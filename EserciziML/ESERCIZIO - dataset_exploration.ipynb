# %%
### importare pandas, seaborn e matplotlib

# %% [markdown]
# ### IMPORT DEI DATI

# %% [markdown]
# I dati sono nella cartella in formato .csv, sotto il nome 'Car details v3.csv'. Caricare il csv in DataFrame Pandas. NB. il dataset originale è disponibile qui: https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho?select=Car+details+v3.csv

# %%
this_path = '/Users/Joe/Dropbox/Formazione ML IFOA/Regression/Cars'

# %%
### importare i dati con pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/zj/566310y53n979szv55jy5t1r0000gn/T/ipykernel_31458/1052306383.py in <module>
#       1 ### importare i dati con pd.read_csv()
# ----> 2 df = pd.read_csv(this_path+'/cars.csv')
#
# NameError: name 'pd' is not defined

# %%
### printare le informazioni sul DataFrame con .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
### printare le prime 5 righe con .head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# ### VALUTAZIONE SOGGETTIVA

# %% [markdown]
# Il TARGET è 'selling_price'. Occhio che il prozzo non è in EURO, ma in una valuta che non conosco, quindi non spaventatevi se vedete numeri molto alti. Scrivere qui sotto in forma di commento qualche osservazione su quali potrebbero essere le variabili più importanti e perchè.

# %%
###

# %% [markdown]
# ### ESPLORAZIONE DELLA VARIABILE TARGET

# %%
### usare sns.displot() per plottare la distribuzione (ricordate di passare un numero adeguato di bins)

# %%
### fare un print di skweness e kurtosis

# %% [markdown]
# ### RELAZIONI CON ALTRE VARIABILI NUMERICHE

# %%
### fare lo scatterplot() di ogni variabile numeriche (km_driven, seats, max_power, engine, mileage) contro il target

# %% [markdown]
# ### RELAZIONI CON ALTRE VARIABILI CATEGORICHE

# %%
### usare sns.boxplot per plottare ogni variabile categorica (year, fuel, seller_type, transmission, owner) contro il target

for col in ['year', 'fuel', 'seller_type', 'transmission', 'owner', 'torque']:
    
    ### ...
    
    plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
    plt.show()

# %% [markdown]
# ### CORRELAZIONI

# %%
# plottare la matrice di correlazione con sns.heatmap() e individuare le variabili più correlate con selling_price, oltre che quelle che sembrano essere collineari tra loro

plt.figure(figsize=(10,9))
### ...........

plt.show()

# %% [markdown]
# Ora vediamo le correlazioni con SalePrice

# %% [markdown]
# Volendo Seaborn mette a disposizione la funzione pairplot() per visualizzare gli scatterplot incrociati e le distribuzioni delle variabili...

# %%
### plottare il pairplot di seaborn
