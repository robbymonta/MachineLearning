# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = pd.read_csv("tips.csv")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sns.set()
#tips = sns.load_dataset("tips")

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# ###CONTROLLO LE VARIABILI CATEGORICHE

# %%
#COUNTPLOT = PLOTTA LA VARIABILE CATEGORICA E MI FA IL COUNT , SEMPLICEMENTE
plt.figure(figsize=(6, 6))
plt.title('Smoker')
sns.countplot(x='smoker', data=tips);

# %%
plt.figure(figsize=(6, 6))
plt.title('Sex')
sns.countplot(x='sex', data=tips);

# %%
plt.figure(figsize=(6, 6))
plt.title('Day')
sns.countplot(x='day', data=tips);

# %%
plt.figure(figsize=(6, 6))
plt.title('Time')
sns.countplot(x='time', data=tips);

# %%
plt.figure(figsize=(6, 6))
plt.title('Sex')
sns.countplot(y='sex', data=tips)

# %%
pd.plotting.scatter_matrix(tips, figsize=(12,10));

# %%
#psso colorare le varianti categorggìhe  -
sns.pairplot(tips, hue='sex', height=3, aspect=1);

# %%
sns.pairplot(tips, hue='smoker', height=3, aspect=1);

# %%
sns.pairplot(tips, hue='day', height=3, aspect=1);

# %%
sns.pairplot(tips, hue='time', height=3, aspect=1);

# %%
sns.pairplot(tips, hue='size', height=3, aspect=1);

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time", row="sex")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day")

# %%
# importare train_test_split da sklearn.model_selection
from sklearn.model_selection import train_test_split

# %%
X = tips[["total_bill","size"]]
y = tips["tip"]

# %%
# Dividere il dataset in train/test set, utilizzando una test_size=0.25, shuffle=True, random_state=22
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size = 0.3,
                                                    random_state=667
                                                    )

# %%
# features =["tip","size"]
# X_train = train_df[features]
# X_test = test_df[features]
# y_train = train_df['total_bill'].copy()
# y_test = test_df['total_bill'].copy()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ###LINEAR REGRASSION

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model = model.fit(X_train, y_train)

# %%
### fare previsioni sia sul train_set che sul test_set usando la funzione .predict()
train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

# %%
### importare mean_absolute_error e r2_score da sklearn.metrics
from sklearn.metrics import mean_absolute_error, r2_score

# %%
### calcolare MAE e R2 del modello sia sul train_set che sul test_set, e poi printarli
train_mae = mean_absolute_error(y_train, train_preds)
train_r2 = r2_score(y_train, train_preds)

# %%
train_mae
# Out:
# 0.7462998469211106

# %%
train_r2
# Out:
# 0.4802445560045867

# %% [markdown]
# ###kNN NEIGHBOURS REGRESSION
